# %% [markdown]
# <a href="https://colab.research.google.com/github/Abu764/Abu764/blob/main/app_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# today i am learning gemini ai
# google offers one gpu free access,and one tpu free access

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
b=20
a+c
a
# Out:
# 10

# %%
# !pip install google-generativeai
#Install

# %%
import os
import google.generativeai as genai
api_key="AIzaSyARqc6D9TcNaB6fRkdjXmFudRRUshs9NFo"
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/aqa

# %% [markdown]
# # Text model: Gemini_pro

# %%
 model=genai.GenerativeModel("gemini-pro")
 model
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
response=model.generate_content("List of top 5 indian cricketers")
print(response.text)
# Out:
# 1. Sachin Tendulkar
# 2. Virat Kohli
# 3. Sunil Gavaskar
# 4. Kapil Dev
# 5. MS Dhoni

# %%
response=model.generate_content("write a poem")
print(response.text)
# Out:
# In verdant fields, where daisies dance,
# And sunlight paints a vibrant trance,
# A gentle breeze, a whispered plea,
# Stirs flowers' souls, setting them free.
#
# Petals unfold, a symphony of hues,
# Crimson blooms and azure ones, they choose,
# Each blossom smiles, a joyous art,
# A vibrant tapestry that warms the heart.
#
# With every petal, nature's grace,
# A masterpiece, a pure embrace,
# A fragrant chorus, sweet and clear,
# A symphony that fills the air with cheer.
#
# Beneath the sky's celestial dome,
# These floral wonders find their home,
# They bloom and flourish, a sight to behold,
# A testament to beauty, yet untold.
#
# In their embrace, we find solace and peace,
# Their beauty heals, our worries cease,
# A sanctuary of calm amidst life's strife,
# A haven where our souls find life.
#
# Oh, flowers of the field, a precious gift,
# Your vibrant blooms, a vibrant shift,
# May your beauty grace the earth forevermore,
# A symphony of nature, forever to adore.

# %% [markdown]
# image_model

# %%
from PIL import Image

# %%
img=Image.open("/content/OIP.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=295x234>

# %%
import os
import google.generativeai as genai
api_key="AIzaSyARqc6D9TcNaB6fRkdjXmFudRRUshs9NFo"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="write a poem on the image"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  # The Blue Bird
#
# *A bluebird sits on a branch,
# Its feathers shining in the sun.
# It sings a sweet song,
# And my heart is filled with joy.*
#
# *The bluebird is a symbol of hope and happiness,
# And it reminds me that even in the darkest of times,
# There is always beauty to be found.*
#
# *I am grateful for the bluebird,
# And for the reminder that there is always hope.*
#
# *Thank you, bluebird,
# For making my day a little brighter.*

# %%
# !pip install streamlit
# !npm install localtunel
# Out:
# ...
# npm ERR! code E404
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/localtunel - Not found
# npm ERR! 404
# npm ERR! 404  'localtunel@latest' is not in the npm registry.
# npm ERR! 404 You should bug the author to publish it (or use the name yourself!)
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# npm ERR! 404 tarball, folder, http url, or git url.
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /root/.npm/_logs/2024-03-25T13_48_48_228Z-debug.log

# %%
# %%writefile app.py

import streamlit as st
import google.generativeai as genai
from PIL import Image

api_key="AIzaSyARqc6D9TcNaB6fRkdjXmFudRRUshs9NFo"
genai.configure(api_key=api_key)

st.header("Image analytics")

uploaded_file=st.file_uploader("upload an image",type=["png","jpg","jpeg"])

if uploaded_file is not None:
   st.image(Image.open(uploaded_file))


prompt=st.text_input("Enter the text")

if st.button("GET RESPONSE"):
  img=Image.open(uploaded_file)
  model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
  response=model.generate_content([prompt,img])
  st.markdown(response.text)
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.125.250.176
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.250.176:8501
#
# npx: installed 22 in 2.512s
# your url is: https://open-apes-bathe.loca.lt
